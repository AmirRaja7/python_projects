# %% [markdown]
# # Python Pandas Lib

# %%
#1 import libs
import pyforest

# %%
#2 import dataset

df= sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#3.1 exploring data
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
#3.2 knowing the data types of dataset columns 
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#3.3 Summary of the Data
df.describe()       # statistical summary of data       # shows only numeric columns of data
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#3.4 to find no. of rows and columns
df.shape    # (rows, columns)
# Out:
# (891, 15)

# %%
#3.5 Names and no. of columns
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#3.6 indexing data data
df.index        # range of columns and start and ending point
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#3.7 info of a dataset comprises all the individual insights that we have collected so far.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#3.8 finding unique values
df.nunique()

# helps finding the no. of values in columns e.g. 2 means it is a boolean value column,
# 3,4,5,6,7 means this columns has categorical values.
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
#3.9 value_counts
df.count
#This can also be done via info function
# Out:
# <bound method DataFrame.count of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
#3.10
df.value_counts
# Out:
# <bound method DataFrame.value_counts of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ## _4.0_
# * Data cleaning

# %%
#4.1 selection
df.select_dtypes(include='number')      #selecting only numeric data to better sort and understand data
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
df.select_dtypes(include='bool').head(10)       #selecting data based on Boolean variable
# Out:
#    adult_male  alone
# 0        True  False
# 1       False  False
# 2       False   True
# 3       False  False
# 4        True   True
# 5        True   True
# 6        True   True
# 7       False  False
# 8       False  False
# 9       False  False

# %%
df.select_dtypes(include='object')      #selecting data based on Catagories variable
# Out:
#         sex embarked    who  embark_town alive
# 0      male        S    man  Southampton    no
# 1    female        C  woman    Cherbourg   yes
# 2    female        S  woman  Southampton   yes
# 3    female        S  woman  Southampton   yes
# 4      male        S    man  Southampton    no
# ..      ...      ...    ...          ...   ...
# 886    male        S    man  Southampton    no
# 887  female        S  woman  Southampton   yes
# 888  female        S  woman  Southampton    no
# 889    male        C    man    Cherbourg   yes
# 890    male        Q    man   Queenstown    no
#
# [891 rows x 5 columns]

# %%
df.select_dtypes(include='category').head(10)       #selecting data based on category variable
# Out:
#     class deck
# 0   Third  NaN
# 1   First    C
# 2   Third  NaN
# 3   First    C
# 4   Third  NaN
# 5   Third  NaN
# 6   First    E
# 7   Third  NaN
# 8   Third  NaN
# 9  Second  NaN

# %%
df.select_dtypes(include='int')         #selecting data based on Integer variable
# Out:
#      survived  pclass  sibsp  parch
# 0           0       3      1      0
# 1           1       1      1      0
# 2           1       3      0      0
# 3           1       1      1      0
# 4           0       3      0      0
# ..        ...     ...    ...    ...
# 886         0       2      0      0
# 887         1       1      0      0
# 888         0       3      1      2
# 889         1       1      0      0
# 890         0       3      0      0
#
# [891 rows x 4 columns]

# %%
df.select_dtypes(include='datetime')         #selecting data based on datetime variable
print("None of the column in Titanic dataset is based on 'datetime' variable")      #this dataset has no column with datetime based variables
# Out:
# None of the column in Titanic dataset is based on 'datetime' variable

# %% [markdown]
# ## _df.drop(['deck','parch'], axis=1, inplace=True)_
# * This command may also show errors because once this runs the column gets removed, Dataset gets updated and this shows "required Columns are unavailable in the data"
# * If you need that column again in the dataset than re-run the code from the beginning and commit this line of code.

# %%
#4.2 dropping un-required columns

df.drop(['parch'], axis=1, inplace=True)

# axis 0= row, axis1= column
# Inplace= True means that the column will be removed from the dataset and dataset will be updated.

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp     fare embarked  class    who  \
# 0         0       3    male  22.0      1   7.2500        S  Third    man
# 1         1       1  female  38.0      1  71.2833        C  First  woman
# 2         1       3  female  26.0      0   7.9250        S  Third  woman
# 3         1       1  female  35.0      1  53.1000        S  First  woman
# 4         0       3    male  35.0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
# 4.3 Transposing the Dataset
df.T            # this can be helpful in some cases
# Out:
#                      0          1            2            3            4    \
# survived               0          1            1            1            0
# pclass                 3          1            3            1            3
# sex                 male     female       female       female         male
# age                 22.0       38.0         26.0         35.0         35.0
# sibsp                  1          1            0            1            0
# fare                7.25    71.2833        7.925         53.1         8.05
# embarked               S          C            S            S            S
# class              Third      First        Third        First        Third
# who                  man      woman        woman        woman          man
# adult_male          True      False        False        False         True
# deck                 NaN          C          NaN            C          NaN
# ...

# %%
# 4.3B re-transposing the data.

df
# Out:
#      survived  pclass     sex   age  sibsp     fare embarked   class    who  \
# 0           0       3    male  22.0      1   7.2500        S   Third    man
# 1           1       1  female  38.0      1  71.2833        C   First  woman
# 2           1       3  female  26.0      0   7.9250        S   Third  woman
# 3           1       1  female  35.0      1  53.1000        S   First  woman
# 4           0       3    male  35.0      0   8.0500        S   Third    man
# ..        ...     ...     ...   ...    ...      ...      ...     ...    ...
# 886         0       2    male  27.0      0  13.0000        S  Second    man
# 887         1       1  female  19.0      0  30.0000        S   First  woman
# 888         0       3  female   NaN      1  23.4500        S   Third  woman
# 889         1       1    male  26.0      0  30.0000        C   First    man
# 890         0       3    male  32.0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
# 4.4 selecting data based on a specific value

girls= df[df['sex']=='female']
girls
# Out:
#      survived  pclass     sex   age  sibsp     fare embarked   class    who  \
# 1           1       1  female  38.0      1  71.2833        C   First  woman
# 2           1       3  female  26.0      0   7.9250        S   Third  woman
# 3           1       1  female  35.0      1  53.1000        S   First  woman
# 8           1       3  female  27.0      0  11.1333        S   Third  woman
# 9           1       2  female  14.0      1  30.0708        C  Second  child
# ..        ...     ...     ...   ...    ...      ...      ...     ...    ...
# 880         1       2  female  25.0      0  26.0000        S  Second  woman
# 882         0       3  female  22.0      0  10.5167        S   Third  woman
# 885         0       3  female  39.0      0  29.1250        Q   Third  woman
# 887         1       1  female  19.0      0  30.0000        S   First  woman
# 888         0       3  female   NaN      1  23.4500        S   Third  woman
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
girls.shape
# Out:
# (314, 14)

# %%
#4.4B selecting data on basis of NOT-Present in a dataset

boys= df[df['sex']!='female']
boys
# Out:
#      survived  pclass   sex   age  sibsp     fare embarked   class    who  \
# 0           0       3  male  22.0      1   7.2500        S   Third    man
# 4           0       3  male  35.0      0   8.0500        S   Third    man
# 5           0       3  male   NaN      0   8.4583        Q   Third    man
# 6           0       1  male  54.0      0  51.8625        S   First    man
# 7           0       3  male   2.0      3  21.0750        S   Third  child
# ..        ...     ...   ...   ...    ...      ...      ...     ...    ...
# 883         0       2  male  28.0      0  10.5000        S  Second    man
# 884         0       3  male  25.0      0   7.0500        S   Third    man
# 886         0       2  male  27.0      0  13.0000        S  Second    man
# 889         1       1  male  26.0      0  30.0000        C   First    man
# 890         0       3  male  32.0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
boys.shape
# Out:
# (577, 14)

# %%
# 4.4C #4.4B selecting data on basis of multiple values in a dataset

girls_over_40= df[df['sex']=='female' and df['age']>40]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Python ka Chilla Dobara\Day_10\Pandas profiling_EDA_by MAT.ipynb Cell 32 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Python%20ka%20Chilla%20Dobara/Day_10/Pandas%20profiling_EDA_by%20MAT.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> # 4.4C #4.4B selecting data on basis of multiple values in a dataset
# ----> <a href='vscode-notebook-cell:/d%3A/Python%20ka%20Chilla%20Dobara/Day_10/Pandas%20profiling_EDA_by%20MAT.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> girls_over_40= df[df['sex']=='female' and df['age']>40]
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %% [markdown]
# ### What is the diff between df['age']>40 and df[df['age']>40]

# %%
df['age']>40 # it will show only 1-diemensional data i.e only single column where age >40
df[df['age']>40] # it will show all the correspondent columns where age>40 as well as other other entities of similar condition

# %%
df['age']>40
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
df[df['age']>40]
# Out:
#      survived  pclass     sex   age  sibsp     fare embarked   class    who  \
# 6           0       1    male  54.0      0  51.8625        S   First    man
# 11          1       1  female  58.0      0  26.5500        S   First  woman
# 15          1       2  female  55.0      0  16.0000        S  Second  woman
# 33          0       2    male  66.0      0  10.5000        S  Second    man
# 35          0       1    male  42.0      1  52.0000        S   First    man
# ..        ...     ...     ...   ...    ...      ...      ...     ...    ...
# 862         1       1  female  48.0      0  25.9292        S   First  woman
# 865         1       2  female  42.0      0  13.0000        S  Second  woman
# 871         1       1  female  47.0      1  52.5542        S   First  woman
# 873         0       3    male  47.0      0   9.0000        S   Third    man
# 879         1       1  female  56.0      0  83.1583        C   First  woman
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
# combining multiple conditions to find more specified data insights
df[(df['age']>=50) & (df['survived']==1) & (df['fare']>50)]
# Out:
#      survived  pclass     sex   age  sibsp      fare embarked  class    who  \
# 195         1       1  female  58.0      0  146.5208        C  First  woman
# 268         1       1  female  58.0      0  153.4625        S  First  woman
# 275         1       1  female  63.0      1   77.9583        S  First  woman
# 299         1       1  female  50.0      0  247.5208        C  First  woman
# 366         1       1  female  60.0      1   75.2500        C  First  woman
# 496         1       1  female  54.0      1   78.2667        C  First  woman
# 513         1       1  female  54.0      1   59.4000        C  First  woman
# 571         1       1  female  53.0      2   51.4792        S  First  woman
# 587         1       1    male  60.0      1   79.2000        C  First    man
# 591         1       1  female  52.0      1   78.2667        C  First  woman
# 660         1       1    male  50.0      2  133.6500        S  First    man
# ...

# %%
df[(df['age']>=50) & (df['survived']==1) & (df['fare']>50)].shape
# Out:
# (15, 14)

# %%
df[(df['age']>=50) & (df['survived']==1) & (df['fare']>50)].head()
# Out:
#      survived  pclass     sex   age  sibsp      fare embarked  class    who  \
# 195         1       1  female  58.0      0  146.5208        C  First  woman
# 268         1       1  female  58.0      0  153.4625        S  First  woman
# 275         1       1  female  63.0      1   77.9583        S  First  woman
# 299         1       1  female  50.0      0  247.5208        C  First  woman
# 366         1       1  female  60.0      1   75.2500        C  First  woman
#
#      adult_male deck  embark_town alive  alone
# 195       False    B    Cherbourg   yes   True
# 268       False    C  Southampton   yes  False
# 275       False    D  Southampton   yes  False
# 299       False    B    Cherbourg   yes  False
# 366       False    D    Cherbourg   yes  False

# %% [markdown]
# ## _Q: How many persons survived in titanic, who paid more than 50$ fair and aged above 50_

# %%
# setting criteria of how many old ladies survived who paid more than 50 fare
df[(df['age']>=50) & (df['survived']==1) & (df['fare']>50) & (df['sex']=='female')]
# Out:
#      survived  pclass     sex   age  sibsp      fare embarked  class    who  \
# 195         1       1  female  58.0      0  146.5208        C  First  woman
# 268         1       1  female  58.0      0  153.4625        S  First  woman
# 275         1       1  female  63.0      1   77.9583        S  First  woman
# 299         1       1  female  50.0      0  247.5208        C  First  woman
# 366         1       1  female  60.0      1   75.2500        C  First  woman
# 496         1       1  female  54.0      1   78.2667        C  First  woman
# 513         1       1  female  54.0      1   59.4000        C  First  woman
# 571         1       1  female  53.0      2   51.4792        S  First  woman
# 591         1       1  female  52.0      1   78.2667        C  First  woman
# 765         1       1  female  51.0      1   77.9583        S  First  woman
# 820         1       1  female  52.0      1   93.5000        S  First  woman
# ...
