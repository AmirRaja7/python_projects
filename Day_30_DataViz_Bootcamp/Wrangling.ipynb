# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# loading dataset
df = pd.read_excel("D:\Python ka Chilla Dobara\Day_30_DataViz_Bootcamp\data_viz.xlsx")
df.head()
# Out:
#                 timestamp  age        city  weight  height   bmi   salary  \
# 0 2022-11-12 12:48:12.949   31     Karachi    73.0   165.0  26.8  10000.0
# 1 2022-11-12 12:48:14.884   21      Turkey    70.0   170.0  29.3      0.0
# 2 2022-11-12 12:48:15.712   41  FAISALABAD    72.5   156.0  31.2  35000.0
# 3 2022-11-12 12:48:24.195   22  rawalpindi    75.0   155.0  32.0  50000.0
# 4 2022-11-12 12:48:24.567   26      harbin    75.0   179.0  23.4  35000.0
#
#   gender     education    employment vaccine marital status github co pilot  \
# 0   Male     Bachelors  Self Emplyed     Yes        Married             Yes
# 1   Male  Intermediate    Unemployed     Yes          Other             Yes
# 2   Male     Bachelors      Employed     Yes         Single             Yes
# 3   Male     Bachelors  Self Emplyed     Yes         Single             Yes
# 4   Male       Masters    Unemployed     Yes         Single              No
#
#             food
# 0        Biryani
# 1        Biryani
# ...

# %%
df.describe()
# Out:
#              age      weight       height         bmi         salary
# count  90.000000   90.000000    90.000000   90.000000      90.000000
# mean   29.188889   71.973678   183.365624   27.800922   50792.142444
# std     7.235826   18.938757   155.022921   38.054109   63473.832443
# min    18.000000   30.000000    13.716000    2.100000       0.000000
# 25%    23.000000   60.000000   162.365000   20.725000    6250.000000
# 50%    29.000000   70.100000   170.430000   24.750000   30000.000000
# 75%    34.000000   80.000000   177.650000   29.275000   76250.000000
# max    55.000000  163.000000  1615.440000  375.400000  300000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        90 non-null     datetime64[ns]
#  1   age              90 non-null     int64
#  2   city             90 non-null     object
#  3   weight           90 non-null     float64
#  4   height           90 non-null     float64
#  5   bmi              90 non-null     float64
#  6   salary           90 non-null     float64
#  7   gender           90 non-null     object
#  8   education        90 non-null     object
#  9   employment       90 non-null     object
#  10  vaccine          90 non-null     object
#  11  marital status   90 non-null     object
#  12  github co pilot  90 non-null     object
#  13  food             90 non-null     object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(8)
# memory usage: 10.0+ KB

# %%
df.shape # to know the rows and column
# Out:
# (90, 14)

# %%
df[df['height'] > 200]

# How to multipy the specific values in a column
a = df['height']

if a is True < 10:
    a = a *25.5
    
else: 
    a = a
df.head()
# Out:
#                 timestamp  age        city  weight  height   bmi   salary  \
# 0 2022-11-12 12:48:12.949   31     Karachi    73.0   165.0  26.8  10000.0
# 1 2022-11-12 12:48:14.884   21      Turkey    70.0   170.0  29.3      0.0
# 2 2022-11-12 12:48:15.712   41  FAISALABAD    72.5   156.0  31.2  35000.0
# 3 2022-11-12 12:48:24.195   22  rawalpindi    75.0   155.0  32.0  50000.0
# 4 2022-11-12 12:48:24.567   26      harbin    75.0   179.0  23.4  35000.0
#
#   gender     education    employment vaccine marital status github co pilot  \
# 0   Male     Bachelors  Self Emplyed     Yes        Married             Yes
# 1   Male  Intermediate    Unemployed     Yes          Other             Yes
# 2   Male     Bachelors      Employed     Yes         Single             Yes
# 3   Male     Bachelors  Self Emplyed     Yes         Single             Yes
# 4   Male       Masters    Unemployed     Yes         Single              No
#
#             food
# 0        Biryani
# 1        Biryani
# ...

# %%
df.nunique()    # no. of catagorical should be less than 10
# Out:
# timestamp          90
# age                28
# city               56
# weight             57
# height             61
# bmi                69
# salary             45
# gender              2
# education           5
# employment          3
# vaccine             2
# marital status      3
# github co pilot     2
# food                5
# dtype: int64

# %%
sns.countplot()
# Out:
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(x= df["gender"],hue= df['marital status'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# ## Interpretation
# 1. There are more Married males than married females.(19 = 10+ 9), (71 = 28 + 43)
# 2. Ratio of married males is greater than ratio of married females.
# 3. On the other hand no of married males are less than single males.
# 4. There are no female have "Other" Merital Status. (Do not mention the negative point on the top. Mention +ve first)
# ### Ratio
# (19 = 10+ 9), (71 = 28 + 43) There are 40% married males as compared to 55% married females in our data.

# %%
sns.countplot(x= df["gender"],hue= df['github co pilot'])
sns.countplot(x= df["gender"],hue= df['marital status'], palette=['red','yellow','green'])

plt.savefig('count_plot.png')

# %% [markdown]
# ## Interpretation
# 1. According to the provided data ration of males "GitHub Co-pilot" users is greater as compared to the female "GitHub Co-pilot" users.
# 2. If we see the relation between the married users of "GitHub Co-pilot" males are still in greater number for GitHub co-pilot users.
# 3. But if we compare the married and unmarried female users of GitHub Co-pilot than we see an interesting fact that more married females use
#    use GitHub Co-pilot as compared to the unmarried females users of GitHub Co-pilot.

# %%
sns.countplot(x= df["salary"],hue= df['github co pilot'])
# plt.savefig('count_plot.png')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# ## Interpretation
# 1. More user with low salary are using Github Co-Pilot. This indicates that more and more students in pakistan are getting awareness about the usefulness of Github Co-Pilot and other resources of Student Developer pack.
# 2. High-salary professional users are relying less on Github Co-Pilot the reason may be they do not want to spend on monthly fee or they have other sources to get coding help or they
# 3. We need to make more and more students aware about the Github Students Developer Pack.

# %%
df.columns
# Out:
# Index(['timestamp', 'age', 'city', 'weight', 'height', 'bmi', 'salary',
#        'gender', 'education', 'employment', 'vaccine', 'marital status',
#        'github co pilot', 'food'],
#       dtype='object')

# %%
# Bill (we keep it in hue) depends upon the no of people
# make assumption to understand the graph better
plt.scatter(x=df['age'], y=df['weight'], c=df['bmi'])
plt.xlabel('age')
plt.ylabel('weight')
plt.title('DataViz workshop Day02 Scatter Plot of Age vs Tip')
plt.colorbar()
# plt.show()    if graph is not showing then use this

# %% [markdown]
# # Interpretation
# 1. In the visualization we observe that people with increase in age have high tendency to put weight. They should focus on exercise.
# 2. There are a few outliers that show data was
# 3. It also reflects that students are getting more aware about the Benefits and use of GitHub Co-Pilot.

# %%
# draw a scatter plot
sns.scatterplot(data = df, x='age',y= 'salary', hue= 'gender')
# Out:
# <AxesSubplot:xlabel='age', ylabel='salary'>

# %%
# Q3 = Q3+1.5 * IQR
# Q1 = Q1-1.5*IQR

# %%
# # box plot
# sns.boxplot(data= df, x='height')

# # Position of the Outlier
# print(np.where(df['height']>400))


# # Upper bound
# upper = np.where(df['height'] >= (Q3+1.5*IQR))
# # Lower bound
# lower = np.where(df['height'] <= (Q1-1.5*IQR))

# # ''' Removing the Outliers '''
# df.drop(upper[0], inplace = True)
# df.drop(lower[0], inplace = True)

# %%
# Hist plot
sns.histplot(data= df, x='height', bins=10)
# Out:
# <AxesSubplot:xlabel='height', ylabel='Count'>

# %%
# Hist plot
sns.histplot(data= df, x='height', bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='height', ylabel='Count'>

# %%
sns.histplot(data =df[['age', 'height']])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.barplot(data = df, x='age', y='github co pilot')
# sns.histplot(data = df, x='age', y='github co pilot')
# Out:
# <AxesSubplot:xlabel='age', ylabel='github co pilot'>

# %%
sns.catplot(data = df, x='marital status', y='salary', hue='age')

# %%
sns.barplot(data = df, x='marital status', y='salary')  #hue='age')
# Out:
# <AxesSubplot:xlabel='marital status', ylabel='salary'>

# %%
sns.jointplot(data=df, x='weight', y='salary')

# %%
sns.distplot(df['weight'], color='red')
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %% [markdown]
# # Line Plot

# %%
# how to plot a line plot
sns.lineplot(data = df, x='age', y='weight')
# Out:
# <AxesSubplot:xlabel='age', ylabel='weight'>

# %%
# time series line plot in seaborn
import seaborn as sns
# load the data
df = sns.load_dataset('fmri')
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# event based on timeframes
# can be used for time and temperature
# time will be always on x-axis
# line plot
sns.lineplot(data = df, x='timepoint', y='signal', hue = 'event', palette=['red','blue'])
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(data = df, x='timepoint', y='signal', hue = 'event', palette=['red','blue'], linestyle='--')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
# df = sns.load_dataset('tips')
# sns.pairplot(df)
